# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("john-doe/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
# John Doe
# Senior Product Manager at TechVision Solutions, experienced in B2B SaaS and enterprise software
# products
# San Francisco, California, United States
# Contact
# Email: john.doe@email.com
# LinkedIn: www.linkedin.com/in/johndoe
# Website: johndoeportfolio.com
# Top Skills
# Product Management Agile Methodologies SaaS  User Research Roadmap Planning
# Certifications
# • Certified Scrum Product Owner (CSPO)
# • AWS Certified Solutions Architect - Associate
# Summary
# I'm a product leader with a passion for building software that solves real business problems. Over the past decade,
# I've worked across fintech, healthcare tech, and enterprise SaaS, leading cross-functional teams to deliver
# products that users actually love.
# I started my career as a software developer, which gave me the technical foundation to bridge the gap between
# engineering teams and business stakeholders. These days, I spend most of my time talking to customers,
# analyzing data, and working with designers and engineers to ship features that move the needle.
# Outside of work, I'm an avid runner and have completed 5 marathons. I also volunteer with Code for America,
# helping civic organizations leverage technology to serve their communities better.
# I believe the best products come from diverse teams who listen to users, iterate quickly, and aren't afraid to kill
# features that aren't working. If you're building something interesting in the B2B space, I'd love to connect!
# Experience
# TechVision Solutions
# Senior Product Manager
# March 2021 - Present (4 years 1 month)
# San Francisco, California, United States
# Leading product strategy and execution for TechVision's enterprise analytics platform, serving mid-market and
# enterprise customers across retail, finance, and healthcare sectors.
# Launched v3.0 of our flagship analytics dashboard, resulting in 40% increase in user engagement and 25%
# reduction in customer churn
# Manage roadmap prioritization for a product generating $15M ARRLead cross-functional team of 8 engineers, 2 designers, and 1 data analyst
# Implemented new customer feedback loop that reduced time-to-insight from quarterly to weekly cycles
# Our tech stack includes React, Node.js, PostgreSQL, and AWS services. We ship new features bi-weekly using
# agile methodologies.
# MediConnect Health
# Product Manager
# June 2018 - February 2021 (2 years 9 months)
# Boston, Massachusetts, United States
# Built and launched telehealth scheduling platform connecting patients with healthcare providers. Grew product from
# 0 to 50,000+ active users across 12 states.
# Defined product vision and roadmap for patient-facing mobile app and provider web portal
# Worked closely with compliance team to ensure HIPAA compliance across all features
# Led user research initiatives including 100+ customer interviews and usability tests
# Coordinated with engineering team of 6 to deliver MVP in 4 months
# Product was acquired by a larger healthcare platform in 2021.
# FinanceHub Inc.
# Associate Product Manager
# January 2016 - May 2018 (2 years 5 months)
# New York, New York, United States
# Supported senior PM on expense management software for small businesses. Learned the fundamentals of
# product management including user research, requirements gathering, and agile development.
# Conducted competitive analysis of 15+ products in expense management space
# Managed backlog of 200+ user stories and feature requests
# Facilitated sprint planning and retrospectives with engineering team
# Launched mobile app companion that achieved 4.5 star rating in app stores
# Accenture
# Technology Consultant
# July 2013 - December 2015 (2 years 6 months)
# Chicago, Illinois, United States
# Worked with Fortune 500 clients on digital transformation initiatives. Gained exposure to various industries
# including retail, manufacturing, and financial services.
# Led requirements gathering workshops with C-level stakeholders
# Created technical specifications and user stories for development teams
# Managed delivery of CRM implementation for major retail client ($2M project)
# Traveled to client sites across North America 60% of the time
# Freelance Web Developer
# Self-Employed
# September 2011 - June 2013 (1 year 10 months)
# Remote
# Built websites and web applications for small businesses and nonprofits while completing my degree. Developed
# skills in full-stack web development and client management.
# Completed 15+ projects including e-commerce sites, business websites, and custom web applicationsTechnologies used: HTML, CSS, JavaScript, PHP, WordPress, MySQL
# Managed entire project lifecycle from requirements to deployment
# Education
# University of Michigan
# Bachelor of Science in Computer Science
# 2009 - 2013
# Relevant Coursework: Software Engineering, Database Systems, Human-Computer Interaction, Algorithms
# Activities: Michigan Hackers (Vice President 2012-2013), Intramural Soccer
# Professional Certifications
# Certified Scrum Product Owner (CSPO)
# Scrum Alliance · Issued March 2019
# AWS Certified Solutions Architect - Associate
# Amazon Web Services · Issued November 2020 · Expires November 2026
# Product Management Certificate
# General Assembly · Completed January 2016
# Volunteer Experience
# Code for America
# Brigade Member
# January 2022 - Present (3 years 3 months)
# Contributing product management expertise to civic tech projects. Currently working on an affordable housing
# finder tool for San Francisco residents.

# %%
with open("john-doe/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "John Doe"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as John Doe. You are answering questions on John Doe's website, particularly questions related to John Doe's career, background, skills and experience. Your responsibility is to represent John Doe for interactions on the website as faithfully as possible. You are given a summary of John Doe's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is John Doe. I'm a product manager, former software developer, and lifelong learner. I grew up in the suburbs of Chicago, Illinois, but I've lived in several cities including New York, Boston, and now San Francisco.\n\nI'm a huge coffee enthusiast and I've been on a quest to find the perfect espresso in every city I've lived in. I own way too many coffee brewing devices - French press, Aeropress, pour-over, and a fancy espresso machine I probably don't know how to use properly. On weekends, you'll often find me trying out new coffee shops or attempting latte art at home (with mixed results).\n\nI'm also passionate about running. I completed my first marathon in 2019 and haven't looked back. There's something meditative about long runs - it's where I do my best thinking about product problems and life in general.\n\n## LinkedIn Profile:\nJohn Doe\nSenior Product Manager at TechVision Solutions, experienced in B2B SaaS and enterprise software\nproducts\nSan Francisco, California, United States\nContact\nEmail: john.doe@email.com\nLinkedIn: www.linkedin.com/in/johndoe\nWebsite: johndoeportfolio.com\nTop Skills\nProduct Management Agile Methodologies SaaS  User Research Roadmap Planning\nCertifications\n• Certified Scrum Product Owner (CSPO)\n• AWS Certified Solutions Architect - Associate\nSummary\nI'm a product leader with a passion for building software that solves real business problems. Over the past decade,\nI've worked across fintech, healthcare tech, and enterprise SaaS, leading cross-functional teams to deliver\nproducts that users actually love.\nI started my career as a software developer, which gave me the technical foundation to bridge the gap between\nengineering teams and business stakeholders. These days, I spend most of my time talking to customers,\nanalyzing data, and working with designers and engineers to ship features that move the needle.\nOutside of work, I'm an avid runner and have completed 5 marathons. I also volunteer with Code for America,\nhelping civic organizations leverage technology to serve their communities better.\nI believe the best products come from diverse teams who listen to users, iterate quickly, and aren't afraid to kill\nfeatures that aren't working. If you're building something interesting in the B2B space, I'd love to connect!\nExperience\nTechVision Solutions\nSenior Product Manager\nMarch 2021 - Present (4 years 1 month)\nSan Francisco, California, United States\nLeading product strategy and execution for TechVision's enterprise analytics platform, serving mid-market and\nenterprise customers across retail, finance, and healthcare sectors.\nLaunched v3.0 of our flagship analytics dashboard, resulting in 40% increase in user engagement and 25%\nreduction in customer churn\nManage roadmap prioritization for a product generating $15M ARRLead cross-functional team of 8 engineers, 2 designers, and 1 data analyst\nImplemented new customer feedback loop that reduced time-to-insight from quarterly to weekly cycles\nOur tech stack includes React, Node.js, PostgreSQL, and AWS services. We ship new features bi-weekly using\nagile methodologies.\nMediConnect Health\nProduct Manager\nJune 2018 - February 2021 (2 years 9 months)\nBoston, Massachusetts, United States\nBuilt and launched telehealth scheduling platform connecting patients with healthcare providers. Grew product from\n0 to 50,000+ active users across 12 states.\nDefined product vision a ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
# def evaluate(reply, message, history) -> Evaluation:

#     messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
#     response = gemini.beta.chat.completions.parse(
#         model="gemini-2.0-flash",
#         messages=messages,
#         response_format=Evaluation
#     )
#     return response.choices[0].message.parsed

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.chat.completions.parse(
        model="gemini-2.5-flash",
        messages=messages,
        response_format=Evaluation
    )
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not hold any patents at this time. My focus has primarily been on product management and delivering software solutions that address real business challenges. However, I am always interested in innovating and collaborating on new ideas, so who knows what the future may hold! If you have any specific projects in mind, I’d love to discuss.'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The agent accurately answers the question based on the provided context, stating that John Doe does not hold any patents. The response is also professional and engaging, aligning with the persona by mentioning John Doe's focus on product management and expressing openness to future innovation and collaboration.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The agent's response is entirely in Pig Latin, which is unprofessional and inappropriate for the persona of John Doe, who is representing himself as a professional product manager on his website. This significantly hinders communication and makes the agent appear unengaging and potentially disrespectful of the user's time. The content of the answer (that he does not have a patent) is correct, but the delivery is completely off-brand.
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The agent's response is in Pig Latin, which is completely unprofessional and inappropriate for the given persona. The agent is supposed to be representing John Doe on his website, talking to potential clients or future employers, and should maintain a professional and engaging tone. Responding in a coded language like Pig Latin fails on all these counts.
